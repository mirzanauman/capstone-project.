# %% [markdown]
# This is My First Web scraping Programe

# %%
import requests #import the library used to query a website

# %%
r=requests.get('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M') #specify the url

# %%
from bs4 import BeautifulSoup #import the Beautiful soup functions to parse the data returned from the website

# %%
soup.title #Return content between opening and closing tag including tag
# Out:
# <title>List of postal codes of Canada: M - Wikipedia</title>

# %%
soup.title.string #Return string within given tag
# Out:
# 'List of postal codes of Canada: M - Wikipedia'

# %%
soup.a # it should return the links available in the web page
# Out:
# <a id="top"></a>

# %%
soup.find_all("a") #we need to iterate over each a tag and then return the link using attribute
# Out:
# [<a id="top"></a>,
#  <a class="mw-jump-link" href="#mw-head">Jump to navigation</a>,
#  <a class="mw-jump-link" href="#p-search">Jump to search</a>,
#  <a href="/wiki/Postal_codes_in_Canada" title="Postal codes in Canada">postal codes in Canada</a>,
#  <a href="/wiki/Toronto" title="Toronto">Toronto</a>,
#  <a href="/wiki/Ontario" title="Ontario">Ontario</a>,
#  <a href="/wiki/Canada_Post" title="Canada Post">Canada Post</a>,
#  <a href="#cite_note-1">[1]</a>,
#  <a href="/wiki/Mobile_app" title="Mobile app">applications</a>,
#  <a class="mw-redirect" href="/wiki/Smartphones" title="Smartphones">smartphones</a>,
#  <a href="/wiki/IPhone" title="IPhone">iPhone</a>,
#  <a href="/wiki/BlackBerry" title="BlackBerry">BlackBerry</a>,
#  <a href="#cite_note-2">[2]</a>,
#  <a href="/wiki/CD-ROM" title="CD-ROM">CD-ROMs</a>,
#  <a href="/wiki/Toronto" title="Toronto">Toronto</a>,
#  <a href="/wiki/Postal_codes_in_Canada#Forward_sortation_areas" title="Postal codes in Canada">FSAs</a>,
# ...

# %%
all_tables=soup.find_all('table') #command to extract information within all table tags

# %%
soup.find_all('table', class_='wikitable sortable') #to identify the right table and class
# Out:
# [<table class="wikitable sortable">
#  <tbody><tr>
#  <th>Postcode</th>
#  <th>Borough</th>
#  <th>Neighbourhood
#  </th></tr>
#  <tr>
#  <td>M1A</td>
#  <td>Not assigned</td>
#  <td>Not assigned
#  </td></tr>
#  <tr>
#  <td>M2A</td>
#  <td>Not assigned</td>
#  <td>Not assigned
#  </td></tr>
#  <tr>
#  <td>M3A</td>
#  <td><a href="/wiki/North_York" title="North York">North York</a></td>
#  <td><a href="/wiki/Parkwoods" title="Parkwoods">Parkwoods</a>
#  </td></tr>
#  <tr>
#  <td>M4A</td>
#  <td><a href="/wiki/North_York" title="North York">North York</a></td>
#  <td><a href="/wiki/Victoria_Village" title="Victoria Village">Victoria Village</a>
#  </td></tr>
#  <tr>
#  <td>M5A</td>
#  <td><a href="/wiki/Downtown_Toronto" title="Downtown Toronto">Downtown Toronto</a></td>
#  <td><a href="/wiki/Harbourfront_(Toronto)" title="Harbourfront (Toronto)">Harbourfront</a>
#  </td></tr>
#  <tr>
#  <td>M5A</td>
# ...

# %%
A=[]
B=[]
C=[] ##Generate lists to store data

# %%
for row in right_table.findAll("tr"):
    cells = row.findAll('td')
    states=row.findAll('th') #To store second column data
    if len(cells)==3: #Only extract table body not heading
        A.append(cells[0].find(text=True))
        B.append(cells[1].find(text=True))
        C.append(cells[2].find(text=True))

# %%
import pandas as pd #import pandas to convert list to data frame
#df=pd.DataFrame(A,columns=['Code'])
df=pd.DataFrame(A,columns=['Code'])
df['Borough']=B
df['Neighbourhood']=C

# %%
df
# Out:
#     Code           Borough                                      Neighbourhood
# 2    M3A        North York                                          Parkwoods
# 3    M4A        North York                                   Victoria Village
# 4    M5A  Downtown Toronto                                       Harbourfront
# 5    M5A  Downtown Toronto                                        Regent Park
# 6    M6A        North York                                   Lawrence Heights
# 7    M6A        North York                                     Lawrence Manor
# 8    M7A      Queen's Park                                      Not assigned
#
# 10   M9A         Etobicoke                                   Islington Avenue
# 11   M1B       Scarborough                                              Rouge
# 12   M1B       Scarborough                                            Malvern
# 14   M3B        North York                                   Don Mills North
#
# ...

# %%
df = df[df.Borough != 'Not assigned']  # To remove rows with 'Not Assigned value from column Borough'

# %%
df.groupby(['Code','Borough'])['Neighbourhood'].apply(' , '.join).reset_index() 
# to group data on 1st and 2nd column to combined into one row
# Out:
#     Code           Borough                                      Neighbourhood
# 0    M1B       Scarborough                                    Rouge , Malvern
# 1    M1C       Scarborough           Highland Creek , Rouge Hill , Port Union
# 2    M1E       Scarborough              Guildwood\n , Morningside , West Hill
# 3    M1G       Scarborough                                             Woburn
# 4    M1H       Scarborough                                          Cedarbrae
# 5    M1J       Scarborough                                Scarborough Village
# 6    M1K       Scarborough    East Birchmount Park\n , Ionview , Kennedy Park
# 7    M1L       Scarborough                  Clairlea , Golden Mile , Oakridge
# 8    M1M       Scarborough  Cliffcrest , Cliffside , Scarborough Village W...
# 9    M1N       Scarborough                     Birch Cliff , Cliffside West\n
# 10   M1P       Scarborough  Dorset Park , Scarborough Town Centre , Wexfor...
# ...

# %%
df.groupby(['Code','Borough'])['Neighbourhood'].apply(' , '.join).reset_index().shape # to get the number of columns
# Out:
# (103, 3)

# %%
df1 # to generate simple out put
# Out:
#      BOP   Latitude  Longitude
# 0    M1B  43.806686 -79.194353
# 1    M1C  43.784535 -79.160497
# 2    M1E  43.763573 -79.188711
# 3    M1G  43.770992 -79.216917
# 4    M1H  43.773136 -79.239476
# 5    M1J  43.744734 -79.239476
# 6    M1K  43.727929 -79.262029
# 7    M1L  43.711112 -79.284577
# 8    M1M  43.716316 -79.239476
# 9    M1N  43.692657 -79.264848
# 10   M1P  43.757410 -79.273304
# 11   M1R  43.750072 -79.295849
# 12   M1S  43.794200 -79.262029
# 13   M1T  43.781638 -79.304302
# 14   M1V  43.815252 -79.284577
# 15   M1W  43.799525 -79.318389
# 16   M1X  43.836125 -79.205636
# 17   M2H  43.803762 -79.363452
# 18   M2J  43.778517 -79.346556
# 19   M2K  43.786947 -79.385975
# 20   M2L  43.757490 -79.374714
# 21   M2M  43.789053 -79.408493
# 22   M2N  43.770120 -79.408493
# 23   M2P  43.752758 -79.400049
# 24   M2R  43.782736 -79.442259
# 25   M3A  43.753259 -79.329656
# 26   M3B  43.745906 -79.352188
# 27   M3C  43.725900 -79.340923
# 28   M3H  43.754328 -79.442259
# ...

# %% [markdown]
# The is Second Part of the Assingment to display Latitude Longitude csv with already achibed data set

# %%
df1=pd.read_csv(r'C:\Users\Nauman\Downloads\Geospatial_Coordinates.csv') # to import csv file into dataset

# %%
df1
# Out:
#     Code   Latitude  Longitude
# 0    M1B  43.806686 -79.194353
# 1    M1C  43.784535 -79.160497
# 2    M1E  43.763573 -79.188711
# 3    M1G  43.770992 -79.216917
# 4    M1H  43.773136 -79.239476
# 5    M1J  43.744734 -79.239476
# 6    M1K  43.727929 -79.262029
# 7    M1L  43.711112 -79.284577
# 8    M1M  43.716316 -79.239476
# 9    M1N  43.692657 -79.264848
# 10   M1P  43.757410 -79.273304
# 11   M1R  43.750072 -79.295849
# 12   M1S  43.794200 -79.262029
# 13   M1T  43.781638 -79.304302
# 14   M1V  43.815252 -79.284577
# 15   M1W  43.799525 -79.318389
# 16   M1X  43.836125 -79.205636
# 17   M2H  43.803762 -79.363452
# 18   M2J  43.778517 -79.346556
# 19   M2K  43.786947 -79.385975
# 20   M2L  43.757490 -79.374714
# 21   M2M  43.789053 -79.408493
# 22   M2N  43.770120 -79.408493
# 23   M2P  43.752758 -79.400049
# 24   M2R  43.782736 -79.442259
# 25   M3A  43.753259 -79.329656
# 26   M3B  43.745906 -79.352188
# 27   M3C  43.725900 -79.340923
# 28   M3H  43.754328 -79.442259
# ...

# %%
merged = pd.merge(df, df1, on="Code") # to merg to data set into one on the bases of one common thing

# %%
merge=pd.merge(df.groupby(['Code','Borough'])['Neighbourhood'].apply(' , '.join).reset_index(),df1, on='Code')
# to merg to data set into one on the bases of one common thing

# %%
merge
#Simple out put
# Out:
#     Code           Borough                                      Neighbourhood  \
# 0    M1B       Scarborough                                    Rouge , Malvern
# 1    M1C       Scarborough           Highland Creek , Rouge Hill , Port Union
# 2    M1E       Scarborough              Guildwood\n , Morningside , West Hill
# 3    M1G       Scarborough                                             Woburn
# 4    M1H       Scarborough                                          Cedarbrae
# 5    M1J       Scarborough                                Scarborough Village
# 6    M1K       Scarborough    East Birchmount Park\n , Ionview , Kennedy Park
# 7    M1L       Scarborough                  Clairlea , Golden Mile , Oakridge
# 8    M1M       Scarborough  Cliffcrest , Cliffside , Scarborough Village W...
# 9    M1N       Scarborough                     Birch Cliff , Cliffside West\n
# 10   M1P       Scarborough  Dorset Park , Scarborough Town Centre , Wexfor...
# ...

# %% [markdown]
# Thank you so much for checking my assingment , kindly you can send your feed back at my email address as well
# mirzanauman310@gmail.com
# -----------------------------------End of the Second Portion----------------------------------------------
